# %% [markdown]
# # Installing Packages needed and Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from collections import defaultdict
import string
import tensorflow as tf
import re
import os
import time
from tensorflow import keras
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
ENCODER_LEN = 140
DECODER_LEN = 40
BATCH_SIZE = 64
BUFFER_SIZE = BATCH_SIZE*8

# %% [markdown]
# # Dataset
#
# After creating the dataframe we apply Start of Sentence(<SOS>) and End of Sentence(<EOS>) tokens.
# These sentences are then tokenized and padded to fix length.

# %%
news = pd.read_excel("/content/Inshorts Cleaned Data.xlsx",engine = 'openpyxl')
news.drop(['Source ', 'Time ', 'Publish Date'], axis=1, inplace=True)
news.head()
# Out:
#                                             Headline  \
# 0  4 ex-bank officials booked for cheating bank o...
# 1     Supreme Court to go paperless in 6 months: CJI
# 2  At least 3 killed, 30 injured in blast in Sylh...
# 3  Why has Reliance been barred from trading in f...
# 4  Was stopped from entering my own studio at Tim...
#
#                                                Short
# 0  The CBI on Saturday booked four former officia...
# 1  Chief Justice JS Khehar has said the Supreme C...
# 2  At least three people were killed, including a...
# 3  Mukesh Ambani-led Reliance Industries (RIL) wa...
# 4  TV news anchor Arnab Goswami has said he was t...

# %%
news.shape
# Out:
# (55104, 2)

# %%
article = news['Short']
summary = news['Headline']
article = article.apply(lambda x: '<SOS> ' + x + ' <EOS>')
summary = summary.apply(lambda x: '<SOS> ' + x + ' <EOS>')

# %%
def preprocess(text):
    text = re.sub(r"&.[1-9]+;"," ",text)
    return text
article = article.apply(lambda x: preprocess(x))
summary = summary.apply(lambda x: preprocess(x))

# %%
filters = '!"#$%&()*+,-./:;=?@[\\]^_`{|}~\t\n'
oov_token = '<unk>'
article_tokenizer = tf.keras.preprocessing.text.Tokenizer(oov_token=oov_token)
summary_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters=filters, oov_token=oov_token)
article_tokenizer.fit_on_texts(article)
summary_tokenizer.fit_on_texts(summary)
inputs = article_tokenizer.texts_to_sequences(article)
targets = summary_tokenizer.texts_to_sequences(summary)

# %%
ENCODER_VOCAB = len(article_tokenizer.word_index) + 1
DECODER_VOCAB = len(summary_tokenizer.word_index) + 1
print(ENCODER_VOCAB, DECODER_VOCAB)
# Out:
# 76362 29661

# %%
inputs = tf.keras.preprocessing.sequence.pad_sequences(inputs, maxlen=ENCODER_LEN, padding='post', truncating='post')
targets = tf.keras.preprocessing.sequence.pad_sequences(targets, maxlen=DECODER_LEN, padding='post', truncating='post')
inputs = tf.cast(inputs, dtype=tf.int64)
targets = tf.cast(targets, dtype=tf.int64)

# %%
dataset = tf.data.Dataset.from_tensor_slices((inputs, targets)).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# # Transformer Model
#
# The next several blocks of code contain the vanilla Transformer model.

# %%
def get_angles(position, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
    return position * angle_rates

def positional_encoding(position, d_model):
    angle_rads = get_angles(
        np.arange(position)[:, np.newaxis],
        np.arange(d_model)[np.newaxis, :],
        d_model
    )

    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    pos_encoding = angle_rads[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)

def create_padding_mask(seq):
    seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
    return seq[:, tf.newaxis, tf.newaxis, :]

def create_look_ahead_mask(size):
    mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
    return mask

def scaled_dot_product_attention(q, k, v, mask):
    matmul_qk = tf.matmul(q, k, transpose_b=True)

    dk = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

    if mask is not None:
        scaled_attention_logits += (mask * -1e9)

    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)

    output = tf.matmul(attention_weights, v)
    return output, attention_weights

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model

        assert d_model % self.num_heads == 0

        self.depth = d_model // self.num_heads

        self.wq = tf.keras.layers.Dense(d_model)
        self.wk = tf.keras.layers.Dense(d_model)
        self.wv = tf.keras.layers.Dense(d_model)

        self.dense = tf.keras.layers.Dense(d_model)

    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, v, k, q, mask):
        batch_size = tf.shape(q)[0]

        q = self.wq(q)
        k = self.wk(k)
        v = self.wv(v)

        q = self.split_heads(q, batch_size)
        k = self.split_heads(k, batch_size)
        v = self.split_heads(v, batch_size)

        scaled_attention, attention_weights = scaled_dot_product_attention(
            q, k, v, mask)

        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])

        concat_attention = tf.reshape(scaled_attention, (batch_size, -1, self.d_model))
        output = self.dense(concat_attention)

        return output, attention_weights

def point_wise_feed_forward_network(d_model, dff):
    return tf.keras.Sequential([
        tf.keras.layers.Dense(dff, activation='relu'),
        tf.keras.layers.Dense(d_model)
    ])

# %%
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(EncoderLayer, self).__init__()

        self.mha = MultiHeadAttention(d_model, num_heads)
        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):
        attn_output, _ = self.mha(x, x, x, mask)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(x + attn_output)

        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        out2 = self.layernorm2(out1 + ffn_output)

        return out2

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(DecoderLayer, self).__init__()

        self.mha1 = MultiHeadAttention(d_model, num_heads)
        self.mha2 = MultiHeadAttention(d_model, num_heads)

        self.ffn = point_wise_feed_forward_network(d_model, dff)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)
        self.dropout3 = tf.keras.layers.Dropout(rate)


    def call(self, x, enc_output, training, look_ahead_mask, padding_mask):
        attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)
        attn1 = self.dropout1(attn1, training=training)
        out1 = self.layernorm1(attn1 + x)

        attn2, attn_weights_block2 = self.mha2(enc_output, enc_output, out1, padding_mask)
        attn2 = self.dropout2(attn2, training=training)
        out2 = self.layernorm2(attn2 + out1)

        ffn_output = self.ffn(out2)
        ffn_output = self.dropout3(ffn_output, training=training)
        out3 = self.layernorm3(ffn_output + out2)

        return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, maximum_position_encoding, rate=0.1):
        super(Encoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers

        self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
        self.pos_encoding = positional_encoding(maximum_position_encoding, self.d_model)

        self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]

        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):
        seq_len = tf.shape(x)[1]

        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x = self.enc_layers[i](x, training, mask)

        return x

class Decoder(tf.keras.layers.Layer):

    def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size, maximum_position_encoding, rate=0.1):
        super(Decoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers

        self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
        self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)

        self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]
        self.dropout = tf.keras.layers.Dropout(rate)

    def call(self, x, enc_output, training, look_ahead_mask, padding_mask):
        seq_len = tf.shape(x)[1]
        attention_weights = {}

        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x, training=training)

        for i in range(self.num_layers):
            x, block1, block2 = self.dec_layers[i](x, enc_output, training, look_ahead_mask, padding_mask)

            attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
            attention_weights['decoder_layer{}_block2'.format(i+1)] = block2

        return x, attention_weights

# %%
class Transformer(tf.keras.Model):
    def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, target_vocab_size, pe_input, pe_target, rate=0.1):
        super(Transformer, self).__init__()

        self.encoder = Encoder(num_layers, d_model, num_heads, dff, input_vocab_size, pe_input, rate)

        self.decoder = Decoder(num_layers, d_model, num_heads, dff, target_vocab_size, pe_target, rate)

        self.final_layer = tf.keras.layers.Dense(target_vocab_size)

    def call(self, inp, tar, training, enc_padding_mask, look_ahead_mask, dec_padding_mask):
        enc_output = self.encoder(inp, training, enc_padding_mask)

        dec_output, attention_weights = self.decoder(tar, enc_output, training, look_ahead_mask, dec_padding_mask)

        final_output = self.final_layer(dec_output)

        return final_output, attention_weights

# %%
num_layers = 4
d_model = 128
dff = 512
num_heads = 8
dropout_rate = 0.3
EPOCHS = 60

# %% [markdown]
# # Custom Learning Rate

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()

        self.d_model = d_model
        self.warmup_steps = warmup_steps

    def __call__(self, step):
        step = tf.cast(step, tf.float32)  # Ensure step is of float32 type
        d_model_cast = tf.cast(self.d_model, tf.float32)  # Cast d_model to float32

        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps ** -1.5)

        return tf.math.rsqrt(d_model_cast) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

# %%
temp_learning_rate_schedule = CustomSchedule(d_model)

plt.plot(temp_learning_rate_schedule(tf.range(40000, dtype=tf.float32)))
plt.ylabel("Learning Rate")
plt.xlabel("Train Step")
# Out:
# Text(0.5, 0, 'Train Step')

# %% [markdown]
# # Custom Loss and Accuracy

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

def accuracy_function(real, pred):
    accuracies = tf.equal(real, tf.argmax(pred, axis=2))
    #accuracies = tf.cast(accuracies, dtype= tf.float32)

    mask = tf.math.logical_not(tf.math.equal(real, 0))
    accuracies = tf.math.logical_and(mask, accuracies)

    accuracies = tf.cast(accuracies, dtype=tf.float32)
    mask = tf.cast(mask, dtype=tf.float32)
    return tf.reduce_sum(accuracies)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

# %%
transformer = Transformer(
    num_layers=num_layers,
    d_model=d_model,
    num_heads=num_heads,
    dff=dff,
    input_vocab_size=ENCODER_VOCAB,
    target_vocab_size=DECODER_VOCAB,
    pe_input=1000,
    pe_target=1000,
    rate=dropout_rate)

# %%
def create_masks(inp, tar):
    enc_padding_mask = create_padding_mask(inp)
    dec_padding_mask = create_padding_mask(inp)

    look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
    dec_target_padding_mask = create_padding_mask(tar)
    combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)

    return enc_padding_mask, combined_mask, dec_padding_mask

# %%
checkpoint_path = "checkpoints"

ckpt = tf.train.Checkpoint(transformer=transformer, optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print ('Latest checkpoint restored!!')

# %%
@tf.function
def train_step(inp, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]

    enc_padding_mask, combined_mask, dec_padding_mask = create_masks(inp, tar_inp)

    with tf.GradientTape() as tape:
        predictions, _ = transformer(
            inp, tar_inp,
            True,
            enc_padding_mask,
            combined_mask,
            dec_padding_mask
        )
        loss = loss_function(tar_real, predictions)

    gradients = tape.gradient(loss, transformer.trainable_variables)
    optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

    train_loss(loss)
    train_accuracy(accuracy_function(tar_real, predictions))

# %% [markdown]
# # Training the Model

# %%
import matplotlib.pyplot as plt

train_loss_results = []
train_accuracy_results = []

for epoch in range(EPOCHS):
    start = time.time()

    train_loss.reset_states()
    train_accuracy.reset_states()

    for (batch, (inp, tar)) in enumerate(dataset):
        train_step(inp, tar)

        if batch % 100 == 0:
            print(f'Epoch {epoch + 1} Batch {batch} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

    if (epoch + 1) % 5 == 0:
        ckpt_save_path = ckpt_manager.save()
        print ('Saving checkpoint for epoch {} at {}'.format(epoch+1, ckpt_save_path))

    # Store the training loss and accuracy for each epoch
    train_loss_results.append(train_loss.result())
    train_accuracy_results.append(train_accuracy.result())

    print(f'Epoch {epoch + 1} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')
    print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 10.3084 Accuracy 0.0000
# Epoch 1 Batch 100 Loss 10.2072 Accuracy 0.0531
# Epoch 1 Batch 200 Loss 9.9971 Accuracy 0.0739
# Epoch 1 Batch 300 Loss 9.6886 Accuracy 0.0814
# Epoch 1 Batch 400 Loss 9.3456 Accuracy 0.0860
# Epoch 1 Batch 500 Loss 9.0303 Accuracy 0.0898
# Epoch 1 Batch 600 Loss 8.7849 Accuracy 0.0935
# Epoch 1 Batch 700 Loss 8.5921 Accuracy 0.0993
# Epoch 1 Batch 800 Loss 8.4375 Accuracy 0.1041
# Epoch 1 Loss 8.3560 Accuracy 0.1066
# Time taken for 1 epoch: 168.97801995277405 secs
#
# Epoch 2 Batch 0 Loss 7.6506 Accuracy 0.1196
# Epoch 2 Batch 100 Loss 7.4306 Accuracy 0.1158
# Epoch 2 Batch 200 Loss 7.3628 Accuracy 0.1192
# Epoch 2 Batch 300 Loss 7.2986 Accuracy 0.1216
# Epoch 2 Batch 400 Loss 7.2601 Accuracy 0.1242
# Epoch 2 Batch 500 Loss 7.2227 Accuracy 0.1277
# Epoch 2 Batch 600 Loss 7.1830 Accuracy 0.1308
# Epoch 2 Batch 700 Loss 7.1413 Accuracy 0.1339
# Epoch 2 Batch 800 Loss 7.1003 Accuracy 0.1365
# Epoch 2 Loss 7.0744 Accuracy 0.1380
# Time taken for 1 epoch: 120.5516927242279 secs
#
# Epoch 3 Batch 0 Loss 7.2674 Accuracy 0.1150
# Epoch 3 Batch 100 Loss 6.9421 Accuracy 0.1288
# Epoch 3 Batch 200 Loss 6.8861 Accuracy 0.1318
# Epoch 3 Batch 300 Loss 6.8294 Accuracy 0.1351
# Epoch 3 Batch 400 Loss 6.8015 Accuracy 0.1379
# Epoch 3 Batch 500 Loss 6.7678 Accuracy 0.1415
# Epoch 3 Batch 600 Loss 6.7330 Accuracy 0.1450
# Epoch 3 Batch 700 Loss 6.6960 Accuracy 0.1487
# Epoch 3 Batch 800 Loss 6.6540 Accuracy 0.1520
# Epoch 3 Loss 6.6252 Accuracy 0.1541
# Time taken for 1 epoch: 119.40369582176208 secs
#
# Epoch 4 Batch 0 Loss 6.9081 Accuracy 0.1389
# Epoch 4 Batch 100 Loss 6.5543 Accuracy 0.1449
# Epoch 4 Batch 200 Loss 6.4902 Accuracy 0.1489
# Epoch 4 Batch 300 Loss 6.4448 Accuracy 0.1517
# Epoch 4 Batch 400 Loss 6.4204 Accuracy 0.1540
# Epoch 4 Batch 500 Loss 6.3922 Accuracy 0.1571
# Epoch 4 Batch 600 Loss 6.3626 Accuracy 0.1604
# Epoch 4 Batch 700 Loss 6.3246 Accuracy 0.1643
# Epoch 4 Batch 800 Loss 6.2820 Accuracy 0.1680
# Epoch 4 Loss 6.2545 Accuracy 0.1699
# Time taken for 1 epoch: 119.2316632270813 secs
#
# Epoch 5 Batch 0 Loss 6.8362 Accuracy 0.1471
# Epoch 5 Batch 100 Loss 6.2636 Accuracy 0.1546
# Epoch 5 Batch 200 Loss 6.1980 Accuracy 0.1600
# Epoch 5 Batch 300 Loss 6.1468 Accuracy 0.1636
# Epoch 5 Batch 400 Loss 6.1214 Accuracy 0.1665
# Epoch 5 Batch 500 Loss 6.0950 Accuracy 0.1700
# Epoch 5 Batch 600 Loss 6.0642 Accuracy 0.1738
# Epoch 5 Batch 700 Loss 6.0287 Accuracy 0.1783
# Epoch 5 Batch 800 Loss 5.9862 Accuracy 0.1825
# Saving checkpoint for epoch 5 at checkpoints/ckpt-1
# Epoch 5 Loss 5.9576 Accuracy 0.1850
# Time taken for 1 epoch: 119.99342370033264 secs
#
# Epoch 6 Batch 0 Loss 6.5188 Accuracy 0.1664
# Epoch 6 Batch 100 Loss 6.0121 Accuracy 0.1698
# Epoch 6 Batch 200 Loss 5.9328 Accuracy 0.1763
# Epoch 6 Batch 300 Loss 5.8697 Accuracy 0.1813
# Epoch 6 Batch 400 Loss 5.8394 Accuracy 0.1842
# Epoch 6 Batch 500 Loss 5.8087 Accuracy 0.1881
# Epoch 6 Batch 600 Loss 5.7765 Accuracy 0.1920
# Epoch 6 Batch 700 Loss 5.7382 Accuracy 0.1966
# Epoch 6 Batch 800 Loss 5.6943 Accuracy 0.2013
# Epoch 6 Loss 5.6657 Accuracy 0.2039
# Time taken for 1 epoch: 118.61039972305298 secs
#
# Epoch 7 Batch 0 Loss 6.4306 Accuracy 0.1591
# Epoch 7 Batch 100 Loss 5.7472 Accuracy 0.1876
# Epoch 7 Batch 200 Loss 5.6673 Accuracy 0.1939
# Epoch 7 Batch 300 Loss 5.6061 Accuracy 0.1988
# Epoch 7 Batch 400 Loss 5.5794 Accuracy 0.2024
# Epoch 7 Batch 500 Loss 5.5496 Accuracy 0.2062
# Epoch 7 Batch 600 Loss 5.5197 Accuracy 0.2100
# Epoch 7 Batch 700 Loss 5.4835 Accuracy 0.2145
# Epoch 7 Batch 800 Loss 5.4419 Accuracy 0.2190
# Epoch 7 Loss 5.4160 Accuracy 0.2216
# Time taken for 1 epoch: 118.54936265945435 secs
#
# Epoch 8 Batch 0 Loss 5.9428 Accuracy 0.2014
# Epoch 8 Batch 100 Loss 5.5376 Accuracy 0.2039
# Epoch 8 Batch 200 Loss 5.4629 Accuracy 0.2103
# Epoch 8 Batch 300 Loss 5.4024 Accuracy 0.2153
# Epoch 8 Batch 400 Loss 5.3766 Accuracy 0.2184
# Epoch 8 Batch 500 Loss 5.3506 Accuracy 0.2219
# Epoch 8 Batch 600 Loss 5.3224 Accuracy 0.2256
# Epoch 8 Batch 700 Loss 5.2868 Accuracy 0.2304
# Epoch 8 Batch 800 Loss 5.2487 Accuracy 0.2348
# Epoch 8 Loss 5.2236 Accuracy 0.2372
# Time taken for 1 epoch: 118.64459490776062 secs
#
# Epoch 9 Batch 0 Loss 5.8922 Accuracy 0.2023
# Epoch 9 Batch 100 Loss 5.3743 Accuracy 0.2161
# Epoch 9 Batch 200 Loss 5.2965 Accuracy 0.2230
# Epoch 9 Batch 300 Loss 5.2384 Accuracy 0.2288
# Epoch 9 Batch 400 Loss 5.2134 Accuracy 0.2317
# Epoch 9 Batch 500 Loss 5.1863 Accuracy 0.2355
# Epoch 9 Batch 600 Loss 5.1593 Accuracy 0.2391
# Epoch 9 Batch 700 Loss 5.1259 Accuracy 0.2435
# Epoch 9 Batch 800 Loss 5.0890 Accuracy 0.2480
# Epoch 9 Loss 5.0645 Accuracy 0.2507
# Time taken for 1 epoch: 118.62378096580505 secs
#
# Epoch 10 Batch 0 Loss 5.7784 Accuracy 0.2091
# Epoch 10 Batch 100 Loss 5.2389 Accuracy 0.2294
# Epoch 10 Batch 200 Loss 5.1577 Accuracy 0.2363
# Epoch 10 Batch 300 Loss 5.0984 Accuracy 0.2420
# Epoch 10 Batch 400 Loss 5.0737 Accuracy 0.2448
# Epoch 10 Batch 500 Loss 5.0494 Accuracy 0.2480
# Epoch 10 Batch 600 Loss 5.0216 Accuracy 0.2519
# Epoch 10 Batch 700 Loss 4.9913 Accuracy 0.2560
# Epoch 10 Batch 800 Loss 4.9552 Accuracy 0.2605
# Saving checkpoint for epoch 10 at checkpoints/ckpt-2
# Epoch 10 Loss 4.9319 Accuracy 0.2629
# Time taken for 1 epoch: 121.13714289665222 secs
#
# Epoch 11 Batch 0 Loss 5.5175 Accuracy 0.2180
# Epoch 11 Batch 100 Loss 5.1131 Accuracy 0.2400
# Epoch 11 Batch 200 Loss 5.0360 Accuracy 0.2460
# Epoch 11 Batch 300 Loss 4.9786 Accuracy 0.2518
# Epoch 11 Batch 400 Loss 4.9564 Accuracy 0.2548
# Epoch 11 Batch 500 Loss 4.9288 Accuracy 0.2586
# Epoch 11 Batch 600 Loss 4.9053 Accuracy 0.2621
# Epoch 11 Batch 700 Loss 4.8759 Accuracy 0.2662
# Epoch 11 Batch 800 Loss 4.8392 Accuracy 0.2706
# Epoch 11 Loss 4.8177 Accuracy 0.2730
# Time taken for 1 epoch: 118.32341599464417 secs
#
# Epoch 12 Batch 0 Loss 5.5556 Accuracy 0.2049
# Epoch 12 Batch 100 Loss 5.0210 Accuracy 0.2500
# Epoch 12 Batch 200 Loss 4.9335 Accuracy 0.2567
# Epoch 12 Batch 300 Loss 4.8755 Accuracy 0.2623
# Epoch 12 Batch 400 Loss 4.8539 Accuracy 0.2648
# Epoch 12 Batch 500 Loss 4.8298 Accuracy 0.2684
# Epoch 12 Batch 600 Loss 4.8056 Accuracy 0.2715
# Epoch 12 Batch 700 Loss 4.7752 Accuracy 0.2758
# Epoch 12 Batch 800 Loss 4.7405 Accuracy 0.2801
# Epoch 12 Loss 4.7194 Accuracy 0.2827
# Time taken for 1 epoch: 118.45616221427917 secs
#
# Epoch 13 Batch 0 Loss 5.4765 Accuracy 0.2246
# Epoch 13 Batch 100 Loss 4.9411 Accuracy 0.2567
# Epoch 13 Batch 200 Loss 4.8555 Accuracy 0.2631
# Epoch 13 Batch 300 Loss 4.7978 Accuracy 0.2691
# Epoch 13 Batch 400 Loss 4.7721 Accuracy 0.2722
# Epoch 13 Batch 500 Loss 4.7471 Accuracy 0.2755
# Epoch 13 Batch 600 Loss 4.7222 Accuracy 0.2795
# Epoch 13 Batch 700 Loss 4.6914 Accuracy 0.2839
# Epoch 13 Batch 800 Loss 4.6578 Accuracy 0.2882
# Epoch 13 Loss 4.6372 Accuracy 0.2906
# Time taken for 1 epoch: 141.90876483917236 secs
#
# Epoch 14 Batch 0 Loss 5.5052 Accuracy 0.2328
# Epoch 14 Batch 100 Loss 4.8470 Accuracy 0.2652
# Epoch 14 Batch 200 Loss 4.7691 Accuracy 0.2714
# Epoch 14 Batch 300 Loss 4.7147 Accuracy 0.2772
# Epoch 14 Batch 400 Loss 4.6918 Accuracy 0.2796
# Epoch 14 Batch 500 Loss 4.6680 Accuracy 0.2832
# Epoch 14 Batch 600 Loss 4.6439 Accuracy 0.2867
# Epoch 14 Batch 700 Loss 4.6154 Accuracy 0.2909
# Epoch 14 Batch 800 Loss 4.5814 Accuracy 0.2952
# Epoch 14 Loss 4.5619 Accuracy 0.2976
# Time taken for 1 epoch: 118.53850841522217 secs
#
# Epoch 15 Batch 0 Loss 5.1435 Accuracy 0.2423
# Epoch 15 Batch 100 Loss 4.7797 Accuracy 0.2730
# Epoch 15 Batch 200 Loss 4.7043 Accuracy 0.2786
# Epoch 15 Batch 300 Loss 4.6517 Accuracy 0.2842
# Epoch 15 Batch 400 Loss 4.6284 Accuracy 0.2867
# Epoch 15 Batch 500 Loss 4.6001 Accuracy 0.2908
# Epoch 15 Batch 600 Loss 4.5762 Accuracy 0.2941
# Epoch 15 Batch 700 Loss 4.5474 Accuracy 0.2982
# Epoch 15 Batch 800 Loss 4.5126 Accuracy 0.3026
# Saving checkpoint for epoch 15 at checkpoints/ckpt-3
# Epoch 15 Loss 4.4939 Accuracy 0.3050
# Time taken for 1 epoch: 123.9240038394928 secs
#
# Epoch 16 Batch 0 Loss 5.1852 Accuracy 0.2511
# Epoch 16 Batch 100 Loss 4.7167 Accuracy 0.2773
# Epoch 16 Batch 200 Loss 4.6461 Accuracy 0.2825
# Epoch 16 Batch 300 Loss 4.5923 Accuracy 0.2883
# Epoch 16 Batch 400 Loss 4.5685 Accuracy 0.2913
# Epoch 16 Batch 500 Loss 4.5413 Accuracy 0.2955
# Epoch 16 Batch 600 Loss 4.5198 Accuracy 0.2989
# Epoch 16 Batch 700 Loss 4.4908 Accuracy 0.3032
# Epoch 16 Batch 800 Loss 4.4569 Accuracy 0.3078
# Epoch 16 Loss 4.4389 Accuracy 0.3101
# Time taken for 1 epoch: 118.50129747390747 secs
#
# Epoch 17 Batch 0 Loss 5.1067 Accuracy 0.2671
# Epoch 17 Batch 100 Loss 4.6621 Accuracy 0.2841
# Epoch 17 Batch 200 Loss 4.5862 Accuracy 0.2902
# Epoch 17 Batch 300 Loss 4.5347 Accuracy 0.2957
# Epoch 17 Batch 400 Loss 4.5121 Accuracy 0.2987
# Epoch 17 Batch 500 Loss 4.4862 Accuracy 0.3024
# Epoch 17 Batch 600 Loss 4.4649 Accuracy 0.3057
# Epoch 17 Batch 700 Loss 4.4349 Accuracy 0.3100
# Epoch 17 Batch 800 Loss 4.4050 Accuracy 0.3138
# Epoch 17 Loss 4.3864 Accuracy 0.3162
# Time taken for 1 epoch: 118.29600882530212 secs
#
# Epoch 18 Batch 0 Loss 4.9950 Accuracy 0.2486
# Epoch 18 Batch 100 Loss 4.6130 Accuracy 0.2877
# Epoch 18 Batch 200 Loss 4.5434 Accuracy 0.2949
# Epoch 18 Batch 300 Loss 4.4917 Accuracy 0.2999
# Epoch 18 Batch 400 Loss 4.4690 Accuracy 0.3028
# Epoch 18 Batch 500 Loss 4.4418 Accuracy 0.3067
# Epoch 18 Batch 600 Loss 4.4199 Accuracy 0.3104
# Epoch 18 Batch 700 Loss 4.3914 Accuracy 0.3144
# Epoch 18 Batch 800 Loss 4.3585 Accuracy 0.3187
# Epoch 18 Loss 4.3411 Accuracy 0.3210
# Time taken for 1 epoch: 118.26258635520935 secs
#
# Epoch 19 Batch 0 Loss 5.1584 Accuracy 0.2558
# Epoch 19 Batch 100 Loss 4.5661 Accuracy 0.2930
# Epoch 19 Batch 200 Loss 4.5005 Accuracy 0.2990
# Epoch 19 Batch 300 Loss 4.4478 Accuracy 0.3051
# Epoch 19 Batch 400 Loss 4.4252 Accuracy 0.3077
# Epoch 19 Batch 500 Loss 4.3999 Accuracy 0.3114
# Epoch 19 Batch 600 Loss 4.3766 Accuracy 0.3152
# Epoch 19 Batch 700 Loss 4.3473 Accuracy 0.3194
# Epoch 19 Batch 800 Loss 4.3136 Accuracy 0.3237
# Epoch 19 Loss 4.2966 Accuracy 0.3259
# Time taken for 1 epoch: 118.27114081382751 secs
#
# Epoch 20 Batch 0 Loss 5.1128 Accuracy 0.2635
# Epoch 20 Batch 100 Loss 4.5321 Accuracy 0.2992
# Epoch 20 Batch 200 Loss 4.4611 Accuracy 0.3042
# Epoch 20 Batch 300 Loss 4.4095 Accuracy 0.3093
# Epoch 20 Batch 400 Loss 4.3853 Accuracy 0.3123
# Epoch 20 Batch 500 Loss 4.3602 Accuracy 0.3160
# Epoch 20 Batch 600 Loss 4.3369 Accuracy 0.3196
# Epoch 20 Batch 700 Loss 4.3061 Accuracy 0.3241
# Epoch 20 Batch 800 Loss 4.2749 Accuracy 0.3283
# Saving checkpoint for epoch 20 at checkpoints/ckpt-4
# Epoch 20 Loss 4.2573 Accuracy 0.3307
# Time taken for 1 epoch: 124.55633187294006 secs
#
# Epoch 21 Batch 0 Loss 4.7299 Accuracy 0.2961
# Epoch 21 Batch 100 Loss 4.5004 Accuracy 0.3025
# Epoch 21 Batch 200 Loss 4.4274 Accuracy 0.3088
# Epoch 21 Batch 300 Loss 4.3728 Accuracy 0.3142
# Epoch 21 Batch 400 Loss 4.3494 Accuracy 0.3169
# Epoch 21 Batch 500 Loss 4.3259 Accuracy 0.3207
# Epoch 21 Batch 600 Loss 4.3017 Accuracy 0.3242
# Epoch 21 Batch 700 Loss 4.2711 Accuracy 0.3287
# Epoch 21 Batch 800 Loss 4.2393 Accuracy 0.3329
# Epoch 21 Loss 4.2214 Accuracy 0.3353
# Time taken for 1 epoch: 118.43443942070007 secs
#
# Epoch 22 Batch 0 Loss 5.1338 Accuracy 0.2615
# Epoch 22 Batch 100 Loss 4.4754 Accuracy 0.3065
# Epoch 22 Batch 200 Loss 4.4039 Accuracy 0.3121
# Epoch 22 Batch 300 Loss 4.3468 Accuracy 0.3177
# Epoch 22 Batch 400 Loss 4.3256 Accuracy 0.3201
# Epoch 22 Batch 500 Loss 4.2974 Accuracy 0.3244
# Epoch 22 Batch 600 Loss 4.2737 Accuracy 0.3279
# Epoch 22 Batch 700 Loss 4.2430 Accuracy 0.3322
# Epoch 22 Batch 800 Loss 4.2107 Accuracy 0.3364
# Epoch 22 Loss 4.1940 Accuracy 0.3388
# Time taken for 1 epoch: 118.24449586868286 secs
#
# Epoch 23 Batch 0 Loss 4.8598 Accuracy 0.2681
# Epoch 23 Batch 100 Loss 4.4447 Accuracy 0.3086
# Epoch 23 Batch 200 Loss 4.3696 Accuracy 0.3155
# Epoch 23 Batch 300 Loss 4.3177 Accuracy 0.3210
# Epoch 23 Batch 400 Loss 4.2955 Accuracy 0.3237
# Epoch 23 Batch 500 Loss 4.2672 Accuracy 0.3282
# Epoch 23 Batch 600 Loss 4.2436 Accuracy 0.3315
# Epoch 23 Batch 700 Loss 4.2143 Accuracy 0.3357
# Epoch 23 Batch 800 Loss 4.1818 Accuracy 0.3402
# Epoch 23 Loss 4.1656 Accuracy 0.3425
# Time taken for 1 epoch: 118.38782477378845 secs
#
# Epoch 24 Batch 0 Loss 5.0584 Accuracy 0.2587
# Epoch 24 Batch 100 Loss 4.4165 Accuracy 0.3118
# Epoch 24 Batch 200 Loss 4.3427 Accuracy 0.3184
# Epoch 24 Batch 300 Loss 4.2917 Accuracy 0.3244
# Epoch 24 Batch 400 Loss 4.2678 Accuracy 0.3270
# Epoch 24 Batch 500 Loss 4.2425 Accuracy 0.3315
# Epoch 24 Batch 600 Loss 4.2211 Accuracy 0.3349
# Epoch 24 Batch 700 Loss 4.1920 Accuracy 0.3392
# Epoch 24 Batch 800 Loss 4.1593 Accuracy 0.3434
# Epoch 24 Loss 4.1432 Accuracy 0.3457
# Time taken for 1 epoch: 118.5694420337677 secs
#
# Epoch 25 Batch 0 Loss 4.8567 Accuracy 0.2747
# Epoch 25 Batch 100 Loss 4.3912 Accuracy 0.3147
# Epoch 25 Batch 200 Loss 4.3218 Accuracy 0.3204
# Epoch 25 Batch 300 Loss 4.2716 Accuracy 0.3261
# Epoch 25 Batch 400 Loss 4.2459 Accuracy 0.3302
# Epoch 25 Batch 500 Loss 4.2201 Accuracy 0.3345
# Epoch 25 Batch 600 Loss 4.1975 Accuracy 0.3381
# Epoch 25 Batch 700 Loss 4.1681 Accuracy 0.3426
# Epoch 25 Batch 800 Loss 4.1365 Accuracy 0.3466
# Saving checkpoint for epoch 25 at checkpoints/ckpt-5
# Epoch 25 Loss 4.1203 Accuracy 0.3491
# Time taken for 1 epoch: 124.49747586250305 secs
#
# Epoch 26 Batch 0 Loss 5.0696 Accuracy 0.2652
# Epoch 26 Batch 100 Loss 4.3615 Accuracy 0.3202
# Epoch 26 Batch 200 Loss 4.2917 Accuracy 0.3254
# Epoch 26 Batch 300 Loss 4.2428 Accuracy 0.3307
# Epoch 26 Batch 400 Loss 4.2186 Accuracy 0.3341
# Epoch 26 Batch 500 Loss 4.1956 Accuracy 0.3378
# Epoch 26 Batch 600 Loss 4.1720 Accuracy 0.3413
# Epoch 26 Batch 700 Loss 4.1424 Accuracy 0.3455
# Epoch 26 Batch 800 Loss 4.1107 Accuracy 0.3498
# Epoch 26 Loss 4.0939 Accuracy 0.3521
# Time taken for 1 epoch: 118.31829833984375 secs
#
# Epoch 27 Batch 0 Loss 4.9647 Accuracy 0.2532
# Epoch 27 Batch 100 Loss 4.3283 Accuracy 0.3225
# Epoch 27 Batch 200 Loss 4.2613 Accuracy 0.3272
# Epoch 27 Batch 300 Loss 4.2114 Accuracy 0.3328
# Epoch 27 Batch 400 Loss 4.1916 Accuracy 0.3357
# Epoch 27 Batch 500 Loss 4.1647 Accuracy 0.3401
# Epoch 27 Batch 600 Loss 4.1427 Accuracy 0.3436
# Epoch 27 Batch 700 Loss 4.1125 Accuracy 0.3482
# Epoch 27 Batch 800 Loss 4.0813 Accuracy 0.3527
# Epoch 27 Loss 4.0638 Accuracy 0.3551
# Time taken for 1 epoch: 118.21936392784119 secs
#
# Epoch 28 Batch 0 Loss 4.6182 Accuracy 0.3043
# Epoch 28 Batch 100 Loss 4.2991 Accuracy 0.3262
# Epoch 28 Batch 200 Loss 4.2301 Accuracy 0.3312
# Epoch 28 Batch 300 Loss 4.1885 Accuracy 0.3361
# Epoch 28 Batch 400 Loss 4.1645 Accuracy 0.3388
# Epoch 28 Batch 500 Loss 4.1370 Accuracy 0.3434
# Epoch 28 Batch 600 Loss 4.1139 Accuracy 0.3470
# Epoch 28 Batch 700 Loss 4.0818 Accuracy 0.3518
# Epoch 28 Batch 800 Loss 4.0523 Accuracy 0.3557
# Epoch 28 Loss 4.0356 Accuracy 0.3579
# Time taken for 1 epoch: 118.17924499511719 secs
#
# Epoch 29 Batch 0 Loss 4.7941 Accuracy 0.2923
# Epoch 29 Batch 100 Loss 4.2742 Accuracy 0.3275
# Epoch 29 Batch 200 Loss 4.2037 Accuracy 0.3338
# Epoch 29 Batch 300 Loss 4.1579 Accuracy 0.3391
# Epoch 29 Batch 400 Loss 4.1341 Accuracy 0.3417
# Epoch 29 Batch 500 Loss 4.1085 Accuracy 0.3457
# Epoch 29 Batch 600 Loss 4.0855 Accuracy 0.3491
# Epoch 29 Batch 700 Loss 4.0543 Accuracy 0.3536
# Epoch 29 Batch 800 Loss 4.0233 Accuracy 0.3581
# Epoch 29 Loss 4.0067 Accuracy 0.3603
# Time taken for 1 epoch: 118.33766770362854 secs
#
# Epoch 30 Batch 0 Loss 4.5178 Accuracy 0.3087
# Epoch 30 Batch 100 Loss 4.2400 Accuracy 0.3298
# Epoch 30 Batch 200 Loss 4.1777 Accuracy 0.3364
# Epoch 30 Batch 300 Loss 4.1300 Accuracy 0.3412
# Epoch 30 Batch 400 Loss 4.1058 Accuracy 0.3447
# Epoch 30 Batch 500 Loss 4.0817 Accuracy 0.3485
# Epoch 30 Batch 600 Loss 4.0561 Accuracy 0.3519
# Epoch 30 Batch 700 Loss 4.0252 Accuracy 0.3562
# Epoch 30 Batch 800 Loss 3.9962 Accuracy 0.3606
# Saving checkpoint for epoch 30 at checkpoints/ckpt-6
# Epoch 30 Loss 3.9789 Accuracy 0.3629
# Time taken for 1 epoch: 124.46414971351624 secs
#
# Epoch 31 Batch 0 Loss 4.5440 Accuracy 0.3196
# Epoch 31 Batch 100 Loss 4.2222 Accuracy 0.3313
# Epoch 31 Batch 200 Loss 4.1506 Accuracy 0.3386
# Epoch 31 Batch 300 Loss 4.0995 Accuracy 0.3434
# Epoch 31 Batch 400 Loss 4.0792 Accuracy 0.3464
# Epoch 31 Batch 500 Loss 4.0504 Accuracy 0.3507
# Epoch 31 Batch 600 Loss 4.0235 Accuracy 0.3546
# Epoch 31 Batch 700 Loss 3.9961 Accuracy 0.3591
# Epoch 31 Batch 800 Loss 3.9648 Accuracy 0.3635
# Epoch 31 Loss 3.9480 Accuracy 0.3657
# Time taken for 1 epoch: 118.67186284065247 secs
#
# Epoch 32 Batch 0 Loss 4.9057 Accuracy 0.2729
# Epoch 32 Batch 100 Loss 4.1922 Accuracy 0.3354
# Epoch 32 Batch 200 Loss 4.1186 Accuracy 0.3420
# Epoch 32 Batch 300 Loss 4.0707 Accuracy 0.3468
# Epoch 32 Batch 400 Loss 4.0476 Accuracy 0.3502
# Epoch 32 Batch 500 Loss 4.0196 Accuracy 0.3541
# Epoch 32 Batch 600 Loss 3.9927 Accuracy 0.3578
# Epoch 32 Batch 700 Loss 3.9639 Accuracy 0.3619
# Epoch 32 Batch 800 Loss 3.9333 Accuracy 0.3663
# Epoch 32 Loss 3.9165 Accuracy 0.3686
# Time taken for 1 epoch: 118.1546323299408 secs
#
# Epoch 33 Batch 0 Loss 4.7364 Accuracy 0.3007
# Epoch 33 Batch 100 Loss 4.1712 Accuracy 0.3372
# Epoch 33 Batch 200 Loss 4.0941 Accuracy 0.3432
# Epoch 33 Batch 300 Loss 4.0468 Accuracy 0.3483
# Epoch 33 Batch 400 Loss 4.0233 Accuracy 0.3518
# Epoch 33 Batch 500 Loss 3.9923 Accuracy 0.3556
# Epoch 33 Batch 600 Loss 3.9659 Accuracy 0.3593
# Epoch 33 Batch 700 Loss 3.9360 Accuracy 0.3639
# Epoch 33 Batch 800 Loss 3.9057 Accuracy 0.3681
# Epoch 33 Loss 3.8894 Accuracy 0.3704
# Time taken for 1 epoch: 118.23145985603333 secs
#
# Epoch 34 Batch 0 Loss 4.5749 Accuracy 0.3091
# Epoch 34 Batch 100 Loss 4.1234 Accuracy 0.3415
# Epoch 34 Batch 200 Loss 4.0575 Accuracy 0.3464
# Epoch 34 Batch 300 Loss 4.0128 Accuracy 0.3516
# Epoch 34 Batch 400 Loss 3.9884 Accuracy 0.3546
# Epoch 34 Batch 500 Loss 3.9631 Accuracy 0.3584
# Epoch 34 Batch 600 Loss 3.9371 Accuracy 0.3621
# Epoch 34 Batch 700 Loss 3.9063 Accuracy 0.3666
# Epoch 34 Batch 800 Loss 3.8763 Accuracy 0.3708
# Epoch 34 Loss 3.8586 Accuracy 0.3733
# Time taken for 1 epoch: 118.30257034301758 secs
#
# Epoch 35 Batch 0 Loss 4.5185 Accuracy 0.3168
# Epoch 35 Batch 100 Loss 4.1040 Accuracy 0.3411
# Epoch 35 Batch 200 Loss 4.0348 Accuracy 0.3475
# Epoch 35 Batch 300 Loss 3.9896 Accuracy 0.3528
# Epoch 35 Batch 400 Loss 3.9646 Accuracy 0.3561
# Epoch 35 Batch 500 Loss 3.9380 Accuracy 0.3601
# Epoch 35 Batch 600 Loss 3.9102 Accuracy 0.3643
# Epoch 35 Batch 700 Loss 3.8796 Accuracy 0.3684
# Epoch 35 Batch 800 Loss 3.8499 Accuracy 0.3725
# Saving checkpoint for epoch 35 at checkpoints/ckpt-7
# Epoch 35 Loss 3.8326 Accuracy 0.3750
# Time taken for 1 epoch: 124.49642562866211 secs
#
# Epoch 36 Batch 0 Loss 4.8596 Accuracy 0.2608
# Epoch 36 Batch 100 Loss 4.0713 Accuracy 0.3421
# Epoch 36 Batch 200 Loss 4.0089 Accuracy 0.3486
# Epoch 36 Batch 300 Loss 3.9651 Accuracy 0.3542
# Epoch 36 Batch 400 Loss 3.9402 Accuracy 0.3572
# Epoch 36 Batch 500 Loss 3.9107 Accuracy 0.3621
# Epoch 36 Batch 600 Loss 3.8825 Accuracy 0.3659
# Epoch 36 Batch 700 Loss 3.8529 Accuracy 0.3702
# Epoch 36 Batch 800 Loss 3.8223 Accuracy 0.3748
# Epoch 36 Loss 3.8054 Accuracy 0.3773
# Time taken for 1 epoch: 118.35170197486877 secs
#
# Epoch 37 Batch 0 Loss 4.5361 Accuracy 0.3026
# Epoch 37 Batch 100 Loss 4.0429 Accuracy 0.3452
# Epoch 37 Batch 200 Loss 3.9813 Accuracy 0.3510
# Epoch 37 Batch 300 Loss 3.9381 Accuracy 0.3561
# Epoch 37 Batch 400 Loss 3.9119 Accuracy 0.3591
# Epoch 37 Batch 500 Loss 3.8834 Accuracy 0.3639
# Epoch 37 Batch 600 Loss 3.8569 Accuracy 0.3679
# Epoch 37 Batch 700 Loss 3.8285 Accuracy 0.3724
# Epoch 37 Batch 800 Loss 3.7979 Accuracy 0.3766
# Epoch 37 Loss 3.7807 Accuracy 0.3789
# Time taken for 1 epoch: 118.26760649681091 secs
#
# Epoch 38 Batch 0 Loss 4.4282 Accuracy 0.3220
# Epoch 38 Batch 100 Loss 4.0125 Accuracy 0.3479
# Epoch 38 Batch 200 Loss 3.9537 Accuracy 0.3529
# Epoch 38 Batch 300 Loss 3.9079 Accuracy 0.3589
# Epoch 38 Batch 400 Loss 3.8855 Accuracy 0.3618
# Epoch 38 Batch 500 Loss 3.8551 Accuracy 0.3660
# Epoch 38 Batch 600 Loss 3.8293 Accuracy 0.3700
# Epoch 38 Batch 700 Loss 3.7990 Accuracy 0.3747
# Epoch 38 Batch 800 Loss 3.7675 Accuracy 0.3790
# Epoch 38 Loss 3.7519 Accuracy 0.3812
# Time taken for 1 epoch: 118.17604088783264 secs
#
# Epoch 39 Batch 0 Loss 4.3900 Accuracy 0.3163
# Epoch 39 Batch 100 Loss 3.9829 Accuracy 0.3505
# Epoch 39 Batch 200 Loss 3.9252 Accuracy 0.3566
# Epoch 39 Batch 300 Loss 3.8823 Accuracy 0.3620
# Epoch 39 Batch 400 Loss 3.8596 Accuracy 0.3647
# Epoch 39 Batch 500 Loss 3.8295 Accuracy 0.3693
# Epoch 39 Batch 600 Loss 3.8046 Accuracy 0.3729
# Epoch 39 Batch 700 Loss 3.7752 Accuracy 0.3775
# Epoch 39 Batch 800 Loss 3.7454 Accuracy 0.3815
# Epoch 39 Loss 3.7287 Accuracy 0.3838
# Time taken for 1 epoch: 118.25666046142578 secs
#
# Epoch 40 Batch 0 Loss 4.4136 Accuracy 0.3026
# Epoch 40 Batch 100 Loss 3.9622 Accuracy 0.3505
# Epoch 40 Batch 200 Loss 3.9023 Accuracy 0.3574
# Epoch 40 Batch 300 Loss 3.8612 Accuracy 0.3625
# Epoch 40 Batch 400 Loss 3.8372 Accuracy 0.3657
# Epoch 40 Batch 500 Loss 3.8069 Accuracy 0.3702
# Epoch 40 Batch 600 Loss 3.7816 Accuracy 0.3740
# Epoch 40 Batch 700 Loss 3.7534 Accuracy 0.3781
# Epoch 40 Batch 800 Loss 3.7234 Accuracy 0.3825
# Saving checkpoint for epoch 40 at checkpoints/ckpt-8
# Epoch 40 Loss 3.7078 Accuracy 0.3847
# Time taken for 1 epoch: 124.28703451156616 secs
#
# Epoch 41 Batch 0 Loss 4.3930 Accuracy 0.3122
# Epoch 41 Batch 100 Loss 3.9462 Accuracy 0.3530
# Epoch 41 Batch 200 Loss 3.8852 Accuracy 0.3587
# Epoch 41 Batch 300 Loss 3.8434 Accuracy 0.3638
# Epoch 41 Batch 400 Loss 3.8173 Accuracy 0.3673
# Epoch 41 Batch 500 Loss 3.7878 Accuracy 0.3719
# Epoch 41 Batch 600 Loss 3.7622 Accuracy 0.3757
# Epoch 41 Batch 700 Loss 3.7326 Accuracy 0.3804
# Epoch 41 Batch 800 Loss 3.7020 Accuracy 0.3849
# Epoch 41 Loss 3.6860 Accuracy 0.3874
# Time taken for 1 epoch: 118.30381608009338 secs
#
# Epoch 42 Batch 0 Loss 4.3618 Accuracy 0.3047
# Epoch 42 Batch 100 Loss 3.9234 Accuracy 0.3536
# Epoch 42 Batch 200 Loss 3.8610 Accuracy 0.3604
# Epoch 42 Batch 300 Loss 3.8187 Accuracy 0.3658
# Epoch 42 Batch 400 Loss 3.7963 Accuracy 0.3685
# Epoch 42 Batch 500 Loss 3.7684 Accuracy 0.3731
# Epoch 42 Batch 600 Loss 3.7421 Accuracy 0.3771
# Epoch 42 Batch 700 Loss 3.7142 Accuracy 0.3816
# Epoch 42 Batch 800 Loss 3.6836 Accuracy 0.3860
# Epoch 42 Loss 3.6682 Accuracy 0.3883
# Time taken for 1 epoch: 118.15589261054993 secs
#
# Epoch 43 Batch 0 Loss 4.5453 Accuracy 0.2964
# Epoch 43 Batch 100 Loss 3.9009 Accuracy 0.3562
# Epoch 43 Batch 200 Loss 3.8437 Accuracy 0.3631
# Epoch 43 Batch 300 Loss 3.8025 Accuracy 0.3680
# Epoch 43 Batch 400 Loss 3.7795 Accuracy 0.3707
# Epoch 43 Batch 500 Loss 3.7477 Accuracy 0.3758
# Epoch 43 Batch 600 Loss 3.7234 Accuracy 0.3794
# Epoch 43 Batch 700 Loss 3.6959 Accuracy 0.3838
# Epoch 43 Batch 800 Loss 3.6672 Accuracy 0.3879
# Epoch 43 Loss 3.6499 Accuracy 0.3904
# Time taken for 1 epoch: 118.12314701080322 secs
#
# Epoch 44 Batch 0 Loss 4.2981 Accuracy 0.3386
# Epoch 44 Batch 100 Loss 3.8812 Accuracy 0.3572
# Epoch 44 Batch 200 Loss 3.8235 Accuracy 0.3640
# Epoch 44 Batch 300 Loss 3.7814 Accuracy 0.3701
# Epoch 44 Batch 400 Loss 3.7588 Accuracy 0.3733
# Epoch 44 Batch 500 Loss 3.7318 Accuracy 0.3768
# Epoch 44 Batch 600 Loss 3.7063 Accuracy 0.3806
# Epoch 44 Batch 700 Loss 3.6789 Accuracy 0.3850
# Epoch 44 Batch 800 Loss 3.6494 Accuracy 0.3894
# Epoch 44 Loss 3.6329 Accuracy 0.3917
# Time taken for 1 epoch: 118.14959955215454 secs
#
# Epoch 45 Batch 0 Loss 4.2201 Accuracy 0.3367
# Epoch 45 Batch 100 Loss 3.8762 Accuracy 0.3584
# Epoch 45 Batch 200 Loss 3.8124 Accuracy 0.3661
# Epoch 45 Batch 300 Loss 3.7683 Accuracy 0.3713
# Epoch 45 Batch 400 Loss 3.7444 Accuracy 0.3741
# Epoch 45 Batch 500 Loss 3.7138 Accuracy 0.3787
# Epoch 45 Batch 600 Loss 3.6908 Accuracy 0.3826
# Epoch 45 Batch 700 Loss 3.6641 Accuracy 0.3869
# Epoch 45 Batch 800 Loss 3.6339 Accuracy 0.3913
# Saving checkpoint for epoch 45 at checkpoints/ckpt-9
# Epoch 45 Loss 3.6175 Accuracy 0.3937
# Time taken for 1 epoch: 124.77176785469055 secs
#
# Epoch 46 Batch 0 Loss 4.1737 Accuracy 0.3362
# Epoch 46 Batch 100 Loss 3.8505 Accuracy 0.3596
# Epoch 46 Batch 200 Loss 3.7876 Accuracy 0.3671
# Epoch 46 Batch 300 Loss 3.7477 Accuracy 0.3721
# Epoch 46 Batch 400 Loss 3.7237 Accuracy 0.3757
# Epoch 46 Batch 500 Loss 3.6947 Accuracy 0.3797
# Epoch 46 Batch 600 Loss 3.6709 Accuracy 0.3841
# Epoch 46 Batch 700 Loss 3.6437 Accuracy 0.3886
# Epoch 46 Batch 800 Loss 3.6142 Accuracy 0.3929
# Epoch 46 Loss 3.5980 Accuracy 0.3953
# Time taken for 1 epoch: 118.25046944618225 secs
#
# Epoch 47 Batch 0 Loss 4.0623 Accuracy 0.3416
# Epoch 47 Batch 100 Loss 3.8365 Accuracy 0.3631
# Epoch 47 Batch 200 Loss 3.7721 Accuracy 0.3703
# Epoch 47 Batch 300 Loss 3.7301 Accuracy 0.3748
# Epoch 47 Batch 400 Loss 3.7078 Accuracy 0.3782
# Epoch 47 Batch 500 Loss 3.6792 Accuracy 0.3827
# Epoch 47 Batch 600 Loss 3.6563 Accuracy 0.3857
# Epoch 47 Batch 700 Loss 3.6293 Accuracy 0.3900
# Epoch 47 Batch 800 Loss 3.6002 Accuracy 0.3945
# Epoch 47 Loss 3.5845 Accuracy 0.3967
# Time taken for 1 epoch: 118.26331448554993 secs
#
# Epoch 48 Batch 0 Loss 4.0761 Accuracy 0.3353
# Epoch 48 Batch 100 Loss 3.8194 Accuracy 0.3658
# Epoch 48 Batch 200 Loss 3.7557 Accuracy 0.3715
# Epoch 48 Batch 300 Loss 3.7182 Accuracy 0.3760
# Epoch 48 Batch 400 Loss 3.6938 Accuracy 0.3790
# Epoch 48 Batch 500 Loss 3.6667 Accuracy 0.3837
# Epoch 48 Batch 600 Loss 3.6409 Accuracy 0.3877
# Epoch 48 Batch 700 Loss 3.6145 Accuracy 0.3921
# Epoch 48 Batch 800 Loss 3.5871 Accuracy 0.3962
# Epoch 48 Loss 3.5719 Accuracy 0.3984
# Time taken for 1 epoch: 118.17731809616089 secs
#
# Epoch 49 Batch 0 Loss 4.2336 Accuracy 0.3184
# Epoch 49 Batch 100 Loss 3.7997 Accuracy 0.3656
# Epoch 49 Batch 200 Loss 3.7433 Accuracy 0.3712
# Epoch 49 Batch 300 Loss 3.7081 Accuracy 0.3760
# Epoch 49 Batch 400 Loss 3.6811 Accuracy 0.3792
# Epoch 49 Batch 500 Loss 3.6547 Accuracy 0.3837
# Epoch 49 Batch 600 Loss 3.6295 Accuracy 0.3880
# Epoch 49 Batch 700 Loss 3.6038 Accuracy 0.3926
# Epoch 49 Batch 800 Loss 3.5756 Accuracy 0.3970
# Epoch 49 Loss 3.5595 Accuracy 0.3992
# Time taken for 1 epoch: 118.21830773353577 secs
#
# Epoch 50 Batch 0 Loss 4.2258 Accuracy 0.3549
# Epoch 50 Batch 100 Loss 3.7939 Accuracy 0.3663
# Epoch 50 Batch 200 Loss 3.7338 Accuracy 0.3728
# Epoch 50 Batch 300 Loss 3.6960 Accuracy 0.3785
# Epoch 50 Batch 400 Loss 3.6689 Accuracy 0.3820
# Epoch 50 Batch 500 Loss 3.6413 Accuracy 0.3865
# Epoch 50 Batch 600 Loss 3.6148 Accuracy 0.3906
# Epoch 50 Batch 700 Loss 3.5897 Accuracy 0.3949
# Epoch 50 Batch 800 Loss 3.5624 Accuracy 0.3992
# Saving checkpoint for epoch 50 at checkpoints/ckpt-10
# Epoch 50 Loss 3.5466 Accuracy 0.4015
# Time taken for 1 epoch: 119.37841439247131 secs
#
# Epoch 51 Batch 0 Loss 4.1294 Accuracy 0.3203
# Epoch 51 Batch 100 Loss 3.7800 Accuracy 0.3699
# Epoch 51 Batch 200 Loss 3.7272 Accuracy 0.3753
# Epoch 51 Batch 300 Loss 3.6841 Accuracy 0.3804
# Epoch 51 Batch 400 Loss 3.6561 Accuracy 0.3837
# Epoch 51 Batch 500 Loss 3.6296 Accuracy 0.3876
# Epoch 51 Batch 600 Loss 3.6044 Accuracy 0.3916
# Epoch 51 Batch 700 Loss 3.5796 Accuracy 0.3960
# Epoch 51 Batch 800 Loss 3.5517 Accuracy 0.4003
# Epoch 51 Loss 3.5363 Accuracy 0.4025
# Time taken for 1 epoch: 118.25491571426392 secs
#
# Epoch 52 Batch 0 Loss 4.1766 Accuracy 0.3131
# Epoch 52 Batch 100 Loss 3.7745 Accuracy 0.3700
# Epoch 52 Batch 200 Loss 3.7140 Accuracy 0.3765
# Epoch 52 Batch 300 Loss 3.6740 Accuracy 0.3811
# Epoch 52 Batch 400 Loss 3.6471 Accuracy 0.3846
# Epoch 52 Batch 500 Loss 3.6201 Accuracy 0.3888
# Epoch 52 Batch 600 Loss 3.5953 Accuracy 0.3929
# Epoch 52 Batch 700 Loss 3.5693 Accuracy 0.3974
# Epoch 52 Batch 800 Loss 3.5414 Accuracy 0.4018
# Epoch 52 Loss 3.5262 Accuracy 0.4043
# Time taken for 1 epoch: 118.1171543598175 secs
#
# Epoch 53 Batch 0 Loss 4.0893 Accuracy 0.3385
# Epoch 53 Batch 100 Loss 3.7621 Accuracy 0.3714
# Epoch 53 Batch 200 Loss 3.7063 Accuracy 0.3773
# Epoch 53 Batch 300 Loss 3.6664 Accuracy 0.3822
# Epoch 53 Batch 400 Loss 3.6387 Accuracy 0.3856
# Epoch 53 Batch 500 Loss 3.6095 Accuracy 0.3902
# Epoch 53 Batch 600 Loss 3.5858 Accuracy 0.3939
# Epoch 53 Batch 700 Loss 3.5604 Accuracy 0.3985
# Epoch 53 Batch 800 Loss 3.5329 Accuracy 0.4025
# Epoch 53 Loss 3.5178 Accuracy 0.4049
# Time taken for 1 epoch: 118.13710331916809 secs
#
# Epoch 54 Batch 0 Loss 4.2709 Accuracy 0.3186
# Epoch 54 Batch 100 Loss 3.7521 Accuracy 0.3715
# Epoch 54 Batch 200 Loss 3.6934 Accuracy 0.3779
# Epoch 54 Batch 300 Loss 3.6551 Accuracy 0.3835
# Epoch 54 Batch 400 Loss 3.6305 Accuracy 0.3863
# Epoch 54 Batch 500 Loss 3.5982 Accuracy 0.3913
# Epoch 54 Batch 600 Loss 3.5752 Accuracy 0.3951
# Epoch 54 Batch 700 Loss 3.5480 Accuracy 0.3999
# Epoch 54 Batch 800 Loss 3.5214 Accuracy 0.4041
# Epoch 54 Loss 3.5051 Accuracy 0.4066
# Time taken for 1 epoch: 118.280766248703 secs
#
# Epoch 55 Batch 0 Loss 4.1985 Accuracy 0.3413
# Epoch 55 Batch 100 Loss 3.7432 Accuracy 0.3718
# Epoch 55 Batch 200 Loss 3.6813 Accuracy 0.3794
# Epoch 55 Batch 300 Loss 3.6419 Accuracy 0.3846
# Epoch 55 Batch 400 Loss 3.6207 Accuracy 0.3876
# Epoch 55 Batch 500 Loss 3.5884 Accuracy 0.3920
# Epoch 55 Batch 600 Loss 3.5662 Accuracy 0.3964
# Epoch 55 Batch 700 Loss 3.5376 Accuracy 0.4010
# Epoch 55 Batch 800 Loss 3.5104 Accuracy 0.4053
# Saving checkpoint for epoch 55 at checkpoints/ckpt-11
# Epoch 55 Loss 3.4952 Accuracy 0.4075
# Time taken for 1 epoch: 124.72939705848694 secs
#
# Epoch 56 Batch 0 Loss 4.1275 Accuracy 0.3473
# Epoch 56 Batch 100 Loss 3.7360 Accuracy 0.3737
# Epoch 56 Batch 200 Loss 3.6770 Accuracy 0.3811
# Epoch 56 Batch 300 Loss 3.6369 Accuracy 0.3869
# Epoch 56 Batch 400 Loss 3.6095 Accuracy 0.3897
# Epoch 56 Batch 500 Loss 3.5777 Accuracy 0.3944
# Epoch 56 Batch 600 Loss 3.5561 Accuracy 0.3984
# Epoch 56 Batch 700 Loss 3.5261 Accuracy 0.4033
# Epoch 56 Batch 800 Loss 3.5000 Accuracy 0.4075
# Epoch 56 Loss 3.4849 Accuracy 0.4098
# Time taken for 1 epoch: 118.33007025718689 secs
#
# Epoch 57 Batch 0 Loss 4.1321 Accuracy 0.3191
# Epoch 57 Batch 100 Loss 3.7206 Accuracy 0.3783
# Epoch 57 Batch 200 Loss 3.6647 Accuracy 0.3828
# Epoch 57 Batch 300 Loss 3.6263 Accuracy 0.3884
# Epoch 57 Batch 400 Loss 3.5985 Accuracy 0.3920
# Epoch 57 Batch 500 Loss 3.5707 Accuracy 0.3959
# Epoch 57 Batch 600 Loss 3.5470 Accuracy 0.4001
# Epoch 57 Batch 700 Loss 3.5185 Accuracy 0.4044
# Epoch 57 Batch 800 Loss 3.4908 Accuracy 0.4088
# Epoch 57 Loss 3.4748 Accuracy 0.4111
# Time taken for 1 epoch: 118.36671590805054 secs
#
# Epoch 58 Batch 0 Loss 4.1669 Accuracy 0.3363
# Epoch 58 Batch 100 Loss 3.7204 Accuracy 0.3769
# Epoch 58 Batch 200 Loss 3.6605 Accuracy 0.3835
# Epoch 58 Batch 300 Loss 3.6222 Accuracy 0.3885
# Epoch 58 Batch 400 Loss 3.5954 Accuracy 0.3923
# Epoch 58 Batch 500 Loss 3.5663 Accuracy 0.3967
# Epoch 58 Batch 600 Loss 3.5402 Accuracy 0.4008
# Epoch 58 Batch 700 Loss 3.5119 Accuracy 0.4054
# Epoch 58 Batch 800 Loss 3.4837 Accuracy 0.4098
# Epoch 58 Loss 3.4677 Accuracy 0.4122
# Time taken for 1 epoch: 118.24411582946777 secs
#
# Epoch 59 Batch 0 Loss 4.2529 Accuracy 0.3113
# Epoch 59 Batch 100 Loss 3.7125 Accuracy 0.3777
# Epoch 59 Batch 200 Loss 3.6498 Accuracy 0.3842
# Epoch 59 Batch 300 Loss 3.6100 Accuracy 0.3895
# Epoch 59 Batch 400 Loss 3.5854 Accuracy 0.3929
# Epoch 59 Batch 500 Loss 3.5563 Accuracy 0.3978
# Epoch 59 Batch 600 Loss 3.5312 Accuracy 0.4019
# Epoch 59 Batch 700 Loss 3.5031 Accuracy 0.4067
# Epoch 59 Batch 800 Loss 3.4750 Accuracy 0.4110
# Epoch 59 Loss 3.4587 Accuracy 0.4135
# Time taken for 1 epoch: 118.1666612625122 secs
#
# Epoch 60 Batch 0 Loss 4.0624 Accuracy 0.3454
# Epoch 60 Batch 100 Loss 3.7017 Accuracy 0.3791
# Epoch 60 Batch 200 Loss 3.6367 Accuracy 0.3865
# Epoch 60 Batch 300 Loss 3.5991 Accuracy 0.3916
# Epoch 60 Batch 400 Loss 3.5725 Accuracy 0.3953
# Epoch 60 Batch 500 Loss 3.5452 Accuracy 0.3994
# Epoch 60 Batch 600 Loss 3.5203 Accuracy 0.4033
# Epoch 60 Batch 700 Loss 3.4939 Accuracy 0.4075
# Epoch 60 Batch 800 Loss 3.4653 Accuracy 0.4120
# Saving checkpoint for epoch 60 at checkpoints/ckpt-12
# Epoch 60 Loss 3.4486 Accuracy 0.4144
# Time taken for 1 epoch: 120.82068204879761 secs

# %%
# Plotting the training loss and accuracy over epochs
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(train_loss_results)
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.title('Training Loss over Epochs')

plt.subplot(1, 2, 2)
plt.plot(train_accuracy_results)
plt.xlabel('Epoch')
plt.ylabel('Training Accuracy')
plt.title('Training Accuracy over Epochs')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluation

# %%
def evaluate(input_article):
    input_article = article_tokenizer.texts_to_sequences([input_article])
    input_article = tf.keras.preprocessing.sequence.pad_sequences(input_article, maxlen=ENCODER_LEN,
                                                                   padding='post', truncating='post')

    encoder_input = tf.expand_dims(input_article[0], 0)

    decoder_input = [summary_tokenizer.word_index['<sos>']]
    output = tf.expand_dims(decoder_input, 0)

    for i in range(DECODER_LEN):
        enc_padding_mask, combined_mask, dec_padding_mask = create_masks(encoder_input, output)

        predictions, attention_weights = transformer(
            encoder_input,
            output,
            False,
            enc_padding_mask,
            combined_mask,
            dec_padding_mask
        )

        predictions = predictions[: ,-1:, :]
        predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

        if predicted_id == summary_tokenizer.word_index['<eos>']:
            return tf.squeeze(output, axis=0), attention_weights

        output = tf.concat([output, predicted_id], axis=-1)

    return tf.squeeze(output, axis=0), attention_weights

# %%
def summarize(input_article):
    summarized = evaluate(input_article=input_article)[0].numpy()
    summarized = np.expand_dims(summarized[1:], 0)
    return summary_tokenizer.sequences_to_texts(summarized)[0]

# %% [markdown]
# # Predictions
#
# Below me make predictions on some texts to see how the model is performimg. Since this was a very basic approach the model wont perform that well but it can surely be improved.

# %%
article[5]
# Out:
# '<SOS> A new trailer for the upcoming superhero film  Justice League  was released on Saturday. Based on the DC Comics superhero team, the film stars Ben Affleck as  Batman , Gal Gadot as  Wonder Woman , Ezra Miller as  The Flash  and Jason Momoa as  Aquaman . Directed by Zack Snyder, the film is scheduled to release on November 17, 2017. <EOS>'

# %%
print("Real Headline : ", summary[5][5:-5],"\n Predicted Summary : ", summarize(article[5]))
# Out:
# Real Headline :   New trailer of  Justice League  released
#  Predicted Summary :  new trailer of the jungle book released

# %%
article[20]
# Out:
# '<SOS> The Indian Army, after consultations with the Defence Ministry, is considering cutting down the number of its sahayaks by 25%, which translates to 10,000 jawans. This comes after videos of soldiers alleging that they were often made to perform menial tasks for the officers surfaced online. The sahayak jawans will be moved to army formations and replaced by civilians. <EOS>'

# %%
print("Real Headline : ", summary[20][5:-5],"\nPredicted Summary : ", summarize(article[20]))
# Out:
# Real Headline :   Indian Army considering to reduce its  sahayaks  by 10,000
# Predicted Summary :  army to hold joint terror alert in india

# %%
# !pip install rouge
# Out:
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.16.0)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1

# %%
from rouge import Rouge

def calculate_rouge_scores(summary, reference):
    rouge = Rouge()
    scores = rouge.get_scores(summary, reference, avg=True)
    return scores

for i in range(1, 21):
    print(f"Example {i}:")
    generated_summary = summarize(article[i])
    actual_summary = summary[i][5:-5]
    scores = calculate_rouge_scores(generated_summary, actual_summary)

    print("Actual Summary: ", actual_summary)
    print("Generated Summary: ", generated_summary)
    print("ROUGE Scores: ", scores)
    print("\n")
# Out:
# Example 1:
# Actual Summary:   Supreme Court to go paperless in 6 months: CJI
# Generated Summary:  no change in law against sardar singh
# ROUGE Scores:  {'rouge-1': {'r': 0.1111111111111111, 'p': 0.14285714285714285, 'f': 0.12499999507812519}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.14285714285714285, 'f': 0.12499999507812519}}
#
#
# Example 2:
# Actual Summary:   At least 3 killed, 30 injured in blast in Sylhet, Bangladesh
# Generated Summary:  2 indians killed in bomb attack on mosque
# ROUGE Scores:  {'rouge-1': {'r': 0.1, 'p': 0.125, 'f': 0.11111110617283973}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1, 'p': 0.125, 'f': 0.11111110617283973}}
#
#
# Example 3:
# Actual Summary:   Why has Reliance been barred from trading in futures?
# Generated Summary:  no evidence of zika virus in india says former manager
# ROUGE Scores:  {'rouge-1': {'r': 0.1111111111111111, 'p': 0.1, 'f': 0.1052631529085875}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.1, 'f': 0.1052631529085875}}
#
#
# Example 4:
# Actual Summary:   Was stopped from entering my own studio at Times Now: Arnab
# Generated Summary:  no change in law that i am a mistake hooda
# ROUGE Scores:  {'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}
#
#
# Example 5:
# Actual Summary:   New trailer of  Justice League  released
# Generated Summary:  new trailer of the jungle book released
# ROUGE Scores:  {'rouge-1': {'r': 0.5, 'p': 0.42857142857142855, 'f': 0.4615384565680473}, 'rouge-2': {'r': 0.2, 'p': 0.16666666666666666, 'f': 0.18181817685950424}, 'rouge-l': {'r': 0.5, 'p': 0.42857142857142855, 'f': 0.4615384565680473}}
#
#
# Example 6:
# Actual Summary:   His touch was not right: Shilpa Shinde on sexual harassment
# Generated Summary:  i am a man who said bharat ratna it minister
# ROUGE Scores:  {'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}
#
#
# Example 7:
# Actual Summary:   Anti-Romeo squads must not trouble consenting youths: Yogi
# Generated Summary:  no change in law against politics khanna
# ROUGE Scores:  {'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}
#
#
# Example 8:
# Actual Summary:   Both Romeo and Juliet are welcome in Delhi: AAP Minister
# Generated Summary:  there is no plans to prove patriotism srk
# ROUGE Scores:  {'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}
#
#
# Example 9:
# Actual Summary:   30 blasts occur at ordnance factory in MP,  20 injured
# Generated Summary:  1 600 girls made of a crime in india in q3
# ROUGE Scores:  {'rouge-1': {'r': 0.1, 'p': 0.1, 'f': 0.09999999500000027}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1, 'p': 0.1, 'f': 0.09999999500000027}}
#
#
# Example 10:
# Actual Summary:   Govt dismisses reports of carving out larger Nagaland state
# Generated Summary:  no immediate effect on beef issue in india
# ROUGE Scores:  {'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}
#
#
# Example 11:
# Actual Summary:   White man shouts  you don t belong here  to Sikh-American
# Generated Summary:  man seeks to send up to 10 000 people to police
# ROUGE Scores:  {'rouge-1': {'r': 0.2, 'p': 0.2222222222222222, 'f': 0.21052631080332423}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.2, 'p': 0.2222222222222222, 'f': 0.21052631080332423}}
#
#
# Example 12:
# Actual Summary:   Thousands march in London to protest against Brexit
# Generated Summary:  brazil s ex prez rousseff suspended
# ROUGE Scores:  {'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}
#
#
# Example 13:
# Actual Summary:   US brewer MillerCoors sues HCL Technologies for ₹650 crore
# Generated Summary:  us state to shut down its own website
# ROUGE Scores:  {'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}
#
#
# Example 14:
# Actual Summary:   Kangana gifts herself 3-bedroom bungalow on birthday: Report
# Generated Summary:  sunny leone to appear on feb cover
# ROUGE Scores:  {'rouge-1': {'r': 0.125, 'p': 0.14285714285714285, 'f': 0.13333332835555575}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.125, 'p': 0.14285714285714285, 'f': 0.13333332835555575}}
#
#
# Example 15:
# Actual Summary:   Flipper taught by Warne got me Warner s wicket: Kuldeep
# Generated Summary:  happy birthday party to play lead in australia
# ROUGE Scores:  {'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}
#
#
# Example 16:
# Actual Summary:   Underprivileged kids to fill Wankhede during MI s IPL match
# Generated Summary:  pink ball to be given free in delhi reports
# ROUGE Scores:  {'rouge-1': {'r': 0.1, 'p': 0.1111111111111111, 'f': 0.1052631529085875}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1, 'p': 0.1111111111111111, 'f': 0.1052631529085875}}
#
#
# Example 17:
# Actual Summary:   There s clear, irrefutable evidence of EVM manipulation: AAP
# Generated Summary:  aap leader seeks report on ex gratia in punjab
# ROUGE Scores:  {'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}
#
#
# Example 18:
# Actual Summary:   55% power tariff hike in Bihar slashed to 28% after protests
# Generated Summary:  up govt takes over 200 of the poor by up cm
# ROUGE Scores:  {'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}
#
#
# Example 19:
# Actual Summary:   Don t know about assets of wife: Abdullah in poll affidavit
# Generated Summary:  don t know how to prove patriotism srk
# ROUGE Scores:  {'rouge-1': {'r': 0.18181818181818182, 'p': 0.25, 'f': 0.21052631091412755}, 'rouge-2': {'r': 0.1, 'p': 0.14285714285714285, 'f': 0.11764705397923896}, 'rouge-l': {'r': 0.18181818181818182, 'p': 0.25, 'f': 0.21052631091412755}}
#
#
# Example 20:
# Actual Summary:   Indian Army considering to reduce its  sahayaks  by 10,000
# Generated Summary:  army to hold joint terror alert in india
# ROUGE Scores:  {'rouge-1': {'r': 0.1111111111111111, 'p': 0.125, 'f': 0.11764705384083066}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.125, 'f': 0.11764705384083066}}

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Dictionary of Scores
data = {
    'Example': np.arange(1, 21),
    'Rouge-1 Recall': [0.111, 0.1, 0.111, 0, 0.5, 0, 0, 0, 0.1, 0, 0.2, 0, 0, 0.125, 0, 0.1, 0, 0, 0.1818, 0.1111],
    'Rouge-1 Precision': [0.1428, 0.125, 0.1, 0, 0.4285, 0, 0, 0, 0.1, 0, 0.2222, 0, 0, 0.1428, 0, 0.1111, 0, 0, 0.25, 0.125],
    'Rouge-1 F1-Score': [0.125, 0.1111, 0.1052, 0, 0.4615, 0, 0, 0, 0.1, 0, 0.2105, 0, 0, 0.1333, 0, 0.1052, 0, 0, 0.2105, 0.1176]
}

df = pd.DataFrame(data)

# Plotting
ax = df.plot(x='Example', y=['Rouge-1 Recall', 'Rouge-1 Precision', 'Rouge-1 F1-Score'], kind='bar', figsize=(14, 7))
plt.title('Testing result of Transformer Model for Abstractive Summarization', fontsize=14)
plt.xlabel('Example No.')
plt.ylabel('Scores')
plt.legend(title='ROUGE Metrics')
plt.xticks(rotation=0)
plt.grid(True, which='both', linestyle='--', linewidth='0.5', color='grey', alpha=0.5)
plt.tight_layout()

plt.show()
